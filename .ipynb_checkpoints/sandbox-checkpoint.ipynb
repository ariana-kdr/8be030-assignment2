# %%
# %load_ext autoreload
# %autoreload 2

# %%
# IMPORTS
# %matplotlib inline
import sys
sys.path.append("../code")

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.patches import Patch
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import segmentation_util as util
import segmentation as seg
import segmentation_project as project



np.random.seed(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 17
#      13 from sklearn.pipeline import make_pipeline
#      14 from sklearn.decomposition import PCA
#      15 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#      16
# ---> 17 import segmentation_util as util
#      18 import segmentation as seg
#      19 import segmentation_project as project
#      20
#
# ModuleNotFoundError: No module named 'segmentation_util'
